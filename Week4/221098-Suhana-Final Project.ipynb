# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score

# %%
train = ImageDataGenerator(rescale=1/255)
test = ImageDataGenerator(rescale=1./255)

train_dataset = train.flow_from_directory("/kaggle/input/test-train-data/train/train",target_size=(150,150),batch_size = 16,class_mode = 'binary')
                                         
test_dataset = test.flow_from_directory("/kaggle/input/test-train-data/test/test",target_size=(150,150),batch_size =16,class_mode = 'binary')
# Out:
# Found 557 images belonging to 2 classes.
# Found 140 images belonging to 2 classes.

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2  # 80:20 split
)
train_generator = train_datagen.flow_from_directory(
    '/kaggle/input/test-train-data/train/train',
    target_size=(150, 150),
    batch_size=16,
    class_mode='binary',
    subset='training'  
)
validation_generator = train_datagen.flow_from_directory(
    '/kaggle/input/test-train-data/test/test',
    target_size=(150, 150),
    batch_size=16,
    class_mode='binary',
    subset='validation'  
)
# Out:
# Found 447 images belonging to 2 classes.
# Found 28 images belonging to 2 classes.

# %%
test_dataset.class_indices
# Out:
# {'cats': 0, 'dogs': 1}

# %%
model = keras.Sequential([
    keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    keras.layers.MaxPool2D(2, 2),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPool2D(2, 2),
    keras.layers.Conv2D(128, (3, 3), activation='relu'),
    keras.layers.MaxPool2D(2, 2),
    keras.layers.Conv2D(128, (3, 3), activation='relu'),
    keras.layers.MaxPool2D(2, 2),
    keras.layers.Flatten(),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(train_generator, steps_per_epoch=27, epochs=20, validation_data=validation_generator)
# Out:
# Epoch 1/20
# 27/27 [==============================] - 15s 493ms/step - loss: 0.4681 - accuracy: 0.7958 - val_loss: 0.5633 - val_accuracy: 0.7857
# Epoch 2/20
# 27/27 [==============================] - 12s 453ms/step - loss: 0.4402 - accuracy: 0.8028 - val_loss: 0.4891 - val_accuracy: 0.7857
# Epoch 3/20
# 27/27 [==============================] - 13s 463ms/step - loss: 0.4192 - accuracy: 0.8097 - val_loss: 0.6157 - val_accuracy: 0.7500
# Epoch 4/20
# 27/27 [==============================] - 13s 470ms/step - loss: 0.4113 - accuracy: 0.8353 - val_loss: 0.5708 - val_accuracy: 0.6786
# Epoch 5/20
# 27/27 [==============================] - 12s 452ms/step - loss: 0.4003 - accuracy: 0.8241 - val_loss: 0.5910 - val_accuracy: 0.7143
# Epoch 6/20
# 27/27 [==============================] - 13s 456ms/step - loss: 0.3741 - accuracy: 0.8492 - val_loss: 0.5165 - val_accuracy: 0.7143
# Epoch 11/20
# 27/27 [==============================] - 13s 482ms/step - loss: 0.3500 - accuracy: 0.8445 - val_loss: 0.5663 - val_accuracy: 0.7500
# Epoch 12/20
# 27/27 [==============================] - 12s 455ms/step - loss: 0.3621 - accuracy: 0.8399 - val_loss: 0.5728 - val_accuracy: 0.6071
# Epoch 13/20
# 27/27 [==============================] - 13s 473ms/step - loss: 0.3634 - accuracy: 0.8469 - val_loss: 0.6950 - val_accuracy: 0.6786
# Epoch 14/20
# 27/27 [==============================] - 12s 457ms/step - loss: 0.3163 - accuracy: 0.8677 - val_loss: 0.4875 - val_accuracy: 0.7500
# Epoch 15/20
# 27/27 [==============================] - 13s 476ms/step - loss: 0.3252 - accuracy: 0.8561 - val_loss: 0.5706 - val_accuracy: 0.7500
# Epoch 16/20
# 27/27 [==============================] - 13s 463ms/step - loss: 0.3048 - accuracy: 0.8701 - val_loss: 0.6717 - val_accuracy: 0.7143
# Epoch 17/20
# 27/27 [==============================] - 13s 462ms/step - loss: 0.3250 - accuracy: 0.8399 - val_loss: 0.5822 - val_accuracy: 0.7500
# Epoch 18/20
# 27/27 [==============================] - 13s 472ms/step - loss: 0.2833 - accuracy: 0.8910 - val_loss: 0.5354 - val_accuracy: 0.7143
# Epoch 19/20
# 27/27 [==============================] - 13s 457ms/step - loss: 0.2760 - accuracy: 0.8794 - val_loss: 0.6031 - val_accuracy: 0.7143
# Epoch 20/20
# 27/27 [==============================] - 13s 473ms/step - loss: 0.3005 - accuracy: 0.8724 - val_loss: 0.5216 - val_accuracy: 0.7857

# %%
test_dataset = test.flow_from_directory("/kaggle/input/test-train-data/test/test",target_size=(150,150),batch_size =16,class_mode = 'binary',color_mode='rgb', shuffle=False,  
                                        )
predictions=model.predict(test_dataset)
predicted_labels = (predictions > 0.38).astype(int).flatten()
true_labels = test_dataset.classes
accuracy = accuracy_score(true_labels, predicted_labels)
f1=f1_score(true_labels,predicted_labels)
print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'f1_score: {f1 * 100:.2f}%')
# Out:
# Found 140 images belonging to 2 classes.
# 9/9 [==============================] - 2s 175ms/step
# Accuracy: 68.57%
# f1_score: 69.44%
